# %%
#import packages
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
#tokenization by word
example_text1="""ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي و هي بدايات الجبر، و من المهم فهم كيف كانت هذه الفكرة الجديدة مهمة، فقد كانت خطوة ثورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة، الجبر كان نظرية موحدة تتيح الأعداد الكسرية و الأعداد اللا كسرية، و قدم وسيلة للتنمية في هذا الموضوع مستقبلا. و جانب آخر مهم لإدخال أفكار الجبر و هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل"""
example_text = """Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely 
the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from 
the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowed rational 
numbers, irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new 
development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the 
subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itself in a 
way which had not happened before.
"""
#english version
token1 = nlp(example_text)
for token in token1:
    print(token.text)
#arabic version
print()
token2 =nlp(example_text1)
for token in token2:
    print(token.text)
# Out:
# Perhaps
# one
# of
# the
# most
# significant
# advances
# made
# by
# Arabic
# mathematics
# began
# at
# this
# time
# with
# the
# work
# of
# al
# -
# Khwarizmi
# ,
# namely
#
#
# the
# beginnings
# of
# algebra
# .
# It
# is
# important
# to
# understand
# just
# how
# significant
# this
# new
# idea
# was
# .
# It
# was
# a
# revolutionary
# move
# away
# from
#
#
# the
# Greek
# concept
# of
# mathematics
# which
# was
# essentially
# geometry
# .
# Algebra
# was
# a
# unifying
# theory
# which
# allowed
# rational
#
#
# numbers
# ,
# irrational
# numbers
# ,
# geometrical
# magnitudes
# ,
# etc
# .
# ,
# to
# all
# be
# treated
# as
# "
# algebraic
# objects
# "
# .
# It
# gave
# mathematics
# a
# whole
# new
#
#
# development
# path
# so
# much
# broader
# in
# concept
# to
# that
# which
# had
# existed
# before
# ,
# and
# provided
# a
# vehicle
# for
# future
# development
# of
# the
#
#
# subject
# .
# Another
# important
# aspect
# of
# the
# introduction
# of
# algebraic
# ideas
# was
# that
# it
# allowed
# mathematics
# to
# be
# applied
# to
# itself
# in
# a
#
#
# way
# which
# had
# not
# happened
# before
# .
#
#
#
# ربما
# كانت
# أحد
# أهم
# التطورات
# التي
# قامت
# بها
# الرياضيات
# العربية
# التي
# بدأت
# في
# هذا
# الوقت
# بعمل
# الخوارزمي
# و
# هي
# بدايات
# الجبر
# ،
# و
# من
# المهم
# فهم
# كيف
# كانت
# هذه
# الفكرة
# الجديدة
# مهمة
# ،
# فقد
# كانت
# خطوة
# ثورية
# بعيدا
# عن
# المفهوم
# اليوناني
# للرياضيات
# التي
# هي
# في
# جوهرها
# هندسة
# ،
# الجبر
# كان
# نظرية
# موحدة
# تتيح
# الأعداد
# الكسرية
# و
# الأعداد
# اللا
# كسرية
# ،
# و
# قدم
# وسيلة
# للتنمية
# في
# هذا
# الموضوع
# مستقبلا
# .
# و
# جانب
# آخر
# مهم
# لإدخال
# أفكار
# الجبر
# و
# هو
# أنه
# سمح
# بتطبيق
# الرياضيات
# على
# نفسها
# بطريقة
# لم
# تحدث
# من
# قبل

# %%
#tokenization by sentence english
for sentence in token1.sents:
    print(sentence)
    
print()
#tokenization by sentence arabic
for sentence in token2.sents:
    print(sentence)
# Out:
# Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely
# the beginnings of algebra.
# It is important to understand just how significant this new idea was.
# It was a revolutionary move away from
# the Greek concept of mathematics which was essentially geometry.
# Algebra was a unifying theory which allowed rational
# numbers, irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects".
# It gave mathematics a whole new
# development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the
# subject.
# Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itself in a
# way which had not happened before.
#
#
# ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي و هي بدايات الجبر،
# و من المهم فهم كيف كانت هذه الفكرة الجديدة مهمة، فقد كانت خطوة ثورية بعيدا عن المفهوم اليوناني للرياضيات التي
# هي في جوهرها هندسة، الجبر
# كان نظرية موحدة تتيح الأعداد الكسرية و الأعداد اللا كسرية، و قدم وسيلة للتنمية في هذا الموضوع مستقبلا.
# و جانب آخر مهم لإدخال أفكار الجبر و هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل

# %%
#pos tags, lemmatization and stop words english
for token in token1:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    
#pos tags, lemmatization and stop words arabic
for token in token2:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Perhaps perhaps ADV RB advmod Xxxxx True True
# one one NUM CD nsubj xxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# most most ADV RBS advmod xxxx True True
# significant significant ADJ JJ amod xxxx True False
# advances advance NOUN NNS pobj xxxx True False
# made make VERB VBN acl xxxx True True
# by by ADP IN agent xx True True
# Arabic arabic ADJ JJ amod Xxxxx True False
# mathematics mathematic NOUN NNS pobj xxxx True False
# began begin VERB VBD ROOT xxxx True False
# at at ADP IN prep xx True True
# this this DET DT det xxxx True True
# time time NOUN NN pobj xxxx True False
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# work work NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# al al PROPN NNP compound xx True False
# - - PUNCT HYPH punct - False False
# Khwarizmi Khwarizmi PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# namely namely ADV RB advmod xxxx True True
#
#
#  SPACE _SP appos
#  False False
# the the DET DT det xxx True True
# beginnings beginning NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True True
# algebra algebra PROPN NNP pobj xxxx True False
# . . PUNCT . punct . False False
# It it PRON PRP nsubj Xx True True
# is be AUX VBZ ROOT xx True True
# important important ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# understand understand VERB VB xcomp xxxx True False
# just just ADV RB advmod xxxx True True
# how how ADV WRB advmod xxx True True
# significant significant ADJ JJ acomp xxxx True False
# this this DET DT det xxxx True True
# new new ADJ JJ amod xxx True False
# idea idea NOUN NN nsubj xxxx True False
# was be AUX VBD ccomp xxx True True
# . . PUNCT . punct . False False
# It it PRON PRP nsubj Xx True True
# was be AUX VBD ROOT xxx True True
# a a DET DT det x True True
# revolutionary revolutionary ADJ JJ amod xxxx True False
# move move NOUN NN attr xxxx True True
# away away ADV RB advmod xxxx True False
# from from ADP IN prep xxxx True True
#
#
#  SPACE _SP pobj
#  False False
# the the DET DT det xxx True True
# Greek greek ADJ JJ amod Xxxxx True False
# concept concept NOUN NN attr xxxx True False
# of of ADP IN prep xx True True
# mathematics mathematic NOUN NNS pobj xxxx True False
# which which DET WDT nsubj xxxx True True
# was be VERB VBD relcl xxx True True
# essentially essentially ADV RB advmod xxxx True False
# geometry geometry NOUN NN attr xxxx True False
# . . PUNCT . punct . False False
# Algebra Algebra PROPN NNP nsubj Xxxxx True False
# was be AUX VBD ROOT xxx True True
# a a DET DT det x True True
# unifying unifying ADJ JJ amod xxxx True False
# theory theory NOUN NN attr xxxx True False
# which which DET WDT nsubj xxxx True True
# allowed allow VERB VBD relcl xxxx True False
# rational rational ADJ JJ amod xxxx True False
#
#
#  SPACE _SP compound
#  False False
# numbers number NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# irrational irrational ADJ JJ amod xxxx True False
# numbers number NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# geometrical geometrical ADJ JJ amod xxxx True False
# magnitudes magnitude NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# etc etc X FW conj xxx True False
# . . X FW conj . False False
# , , PUNCT , punct , False False
# to to AUX IN aux xx True True
# all all DET DT advmod xxx True True
# be be AUX VB auxpass xx True True
# treated treat VERB VBN advcl xxxx True False
# as as ADP IN prep xx True True
# " " PUNCT `` punct " False False
# algebraic algebraic ADJ JJ amod xxxx True False
# objects object NOUN NNS pobj xxxx True False
# " " PUNCT '' punct " False False
# . . PUNCT . punct . False False
# It it PRON PRP nsubj Xx True True
# gave give VERB VBD ROOT xxxx True False
# mathematics mathematic NOUN NNS dative xxxx True False
# a a DET DT det x True True
# whole whole ADJ JJ amod xxxx True True
# new new ADJ JJ amod xxx True False
#
#
#  SPACE _SP compound
#  False False
# development development NOUN NN compound xxxx True False
# path path NOUN NN dobj xxxx True False
# so so ADV RB advmod xx True True
# much much ADV RB advmod xxxx True True
# broader broad ADJ JJR dobj xxxx True False
# in in ADP IN prep xx True True
# concept concept NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
# that that DET DT pobj xxxx True True
# which which DET WDT nsubj xxxx True True
# had have AUX VBD aux xxx True True
# existed exist VERB VBN relcl xxxx True False
# before before ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# provided provide VERB VBD conj xxxx True False
# a a DET DT det x True True
# vehicle vehicle NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# future future ADJ JJ amod xxxx True False
# development development NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
#
#
#  SPACE _SP compound
#  False False
# subject subject NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Another another DET DT det Xxxxx True True
# important important ADJ JJ amod xxxx True False
# aspect aspect NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# introduction introduction NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# algebraic algebraic ADJ JJ amod xxxx True False
# ideas idea NOUN NNS pobj xxxx True False
# was be AUX VBD ROOT xxx True True
# that that SCONJ IN mark xxxx True True
# it it PRON PRP nsubj xx True True
# allowed allow VERB VBD ccomp xxxx True False
# mathematics mathematic NOUN NNS nsubjpass xxxx True False
# to to PART TO aux xx True True
# be be AUX VB auxpass xx True True
# applied apply VERB VBN ccomp xxxx True False
# to to ADP IN prep xx True True
# itself itself PRON PRP pobj xxxx True True
# in in ADP IN prep xx True True
# a a DET DT det x True True
#
#
#  SPACE _SP compound
#  False False
# way way NOUN NN pobj xxx True False
# which which DET WDT nsubj xxxx True True
# had have AUX VBD aux xxx True True
# not not PART RB neg xxx True True
# happened happen VERB VBN relcl xxxx True False
# before before ADV RB advmod xxxx True True
# . . PUNCT . punct . False False
#
#
#  SPACE _SP punct
#  False False
# ربما ربما PROPN NNP nsubj xxxx True False
# كانت كانت PROPN NNP compound xxxx True False
# أحد أحد PROPN NNP compound xxx True False
# أهم أهم PROPN NNP compound xxx True False
# التطورات التطورات VERB VBD nmod xxxx True False
# التي التي PROPN NNP amod xxxx True False
# قامت قامت VERB VBD amod xxxx True False
# بها بها NOUN NN npadvmod xxx True False
# الرياضيات الرياضيات ADJ JJ amod xxxx True False
# العربية العربية NOUN NN compound xxxx True False
# التي التي NOUN NNS nsubj xxxx True False
# بدأت بدأت VERB VBP ROOT xxxx True False
# في في ADP IN prep xx True False
# هذا هذا ADJ JJ compound xxx True False
# الوقت الوقت NOUN NN compound xxxx True False
# بعمل بعمل PROPN NNP compound xxxx True False
# الخوارزمي الخوارزمي VERB VBD pobj xxxx True False
# و و PROPN NNP nmod x True False
# هي هي PROPN NNP nmod xx True False
# بدايات بدايات PROPN NNP compound xxxx True False
# الجبر الجبر PROPN NNP compound xxxx True False
# ، ، PROPN NNP appos ، False False
# و و PROPN NNP nmod x True False
# من من PROPN NNP prep xx True False
# المهم المهم NOUN NN nmod xxxx True False
# فهم فهم PROPN NNP compound xxx True False
# كيف كيف PROPN NNP npadvmod xxx True False
# كانت كانت PROPN NNP nmod xxxx True False
# هذه هذه PROPN NNP compound xxx True False
# الفكرة الفكرة PROPN NNP compound xxxx True False
# الجديدة الجديدة PROPN NNP compound xxxx True False
# مهمة مهمة PROPN NNP conj xxxx True False
# ، ، PROPN NNP punct ، False False
# فقد فقد PROPN NNP compound xxx True False
# كانت كانت PROPN NNP compound xxxx True False
# خطوة خطوة PROPN NNP nsubj xxxx True False
# ثورية ثورية PROPN NNP appos xxxx True False
# بعيدا بعيدا VERB VBZ ROOT xxxx True False
# عن عن PROPN NNP compound xx True False
# المفهوم المفهوم PROPN NNP compound xxxx True False
# اليوناني اليوناني PROPN NNP dobj xxxx True False
# للرياضيات للرياضيات PROPN NNP compound xxxx True False
# التي التي PROPN NNP dobj xxxx True False
# هي هي PROPN NNP intj xx True False
# في في INTJ UH intj xx True False
# جوهرها جوهرها PROPN NNP compound xxxx True False
# هندسة هندسة PROPN NNP compound xxxx True False
# ، ، PROPN NNP nsubj ، False False
# الجبر الجبر PROPN NNP ROOT xxxx True False
# كان كان PROPN NNP compound xxx True False
# نظرية نظرية PROPN NNP compound xxxx True False
# موحدة موحدة PROPN NNP compound xxxx True False
# تتيح تتيح PROPN NNP compound xxxx True False
# الأعداد الأعداد PROPN NNP compound xxxx True False
# الكسرية الكسرية NOUN NN nsubj xxxx True False
# و و PROPN NNP compound x True False
# الأعداد الأعداد NOUN NN compound xxxx True False
# اللا اللا NOUN NNS nsubj xxxx True False
# كسرية كسرية VERB VBP ROOT xxxx True False
# ، ، PROPN NNP dobj ، False False
# و و PROPN NNP compound x True False
# قدم قدم PROPN NNP compound xxx True False
# وسيلة وسيلة NOUN NN compound xxxx True False
# للتنمية للتنمية ADJ JJ nmod xxxx True False
# في في ADP IN advmod xx True False
# هذا هذا PROPN NNP compound xxx True False
# الموضوع الموضوع NOUN NN compound xxxx True False
# مستقبلا مستقبلا PROPN NNP dobj xxxx True False
# . . PUNCT . punct . False False
# و و PRON PRP nmod x True False
# جانب جانب PROPN NNP compound xxxx True False
# آخر آخر NOUN NN compound xxx True False
# مهم مهم NOUN NN compound xxx True False
# لإدخال لإدخال NOUN NN compound xxxx True False
# أفكار أفكار NOUN NNS nsubj xxxx True False
# الجبر الجبر VERB VBD ROOT xxxx True False
# و و PROPN NNP compound x True False
# هو هو PROPN NNP compound xx True False
# أنه أنه PROPN NNP compound xxx True False
# سمح سمح PROPN NNP compound xxx True False
# بتطبيق بتطبيق PROPN NNP compound xxxx True False
# الرياضيات الرياضيات PROPN NNP compound xxxx True False
# على على PROPN NNP compound xxx True False
# نفسها نفسها PROPN NNP compound xxxx True False
# بطريقة بطريقة PROPN NNP dobj xxxx True False
# لم لم PROPN NNP compound xx True False
# تحدث تحدث PROPN NNP ccomp xxxx True False
# من من DET DT prep xx True False
# قبل قبل NOUN NN npadvmod xxx True False

# %%
#Visualizing dependencies
displacy.render(token1, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="29517c0ba52540c1b84c670097f7514d-0" class="displacy" width="24200" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Perhaps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">advances</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Arabic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">mathematics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">began</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">work</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Khwarizmi,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">namely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">beginnings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">algebra.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">important</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">to</tspan>
#     <tspan class="displacy-tag" d

# %%
#Named Entity Recognition
for ent in token1.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Arabic mathematics 53 71 NORP
# al-Khwarizmi 108 120 GPE
# Greek 270 275 NORP
